# %% [markdown]
# # Game of Thrones
#
# Are you a fan of the Game of Thrones series? Let's test it. Let's use the API: <a href="https://anapioficeandfire.com/" target="_blank">https://anapioficeandfire.com/</a> to find out more about the series.

# %% [markdown]
# 1. Import the following libraries:
#
#       * ```requests```
#       * ```pandas```
#       * ```json```

# %%
import requests
import pandas as pd
import json

# %% [markdown]
# 2. Go to the URL indicated in the description above. Using `requests`, get data on a character in the series. It doesn't matter who the character is.

# %%
r=requests.get("https://anapioficeandfire.com/api/characters/583")
r.content
# Out:
# b'{"url":"https://anapioficeandfire.com/api/characters/583","name":"Jon Snow","gender":"Male","culture":"Northmen","born":"In 283 AC","died":"","titles":["Lord Commander of the Night\'s Watch"],"aliases":["Lord Snow","Ned Stark\'s Bastard","The Snow of Winterfell","The Crow-Come-Over","The 998th Lord Commander of the Night\'s Watch","The Bastard of Winterfell","The Black Bastard of the Wall","Lord Crow"],"father":"","mother":"","spouse":"","allegiances":["https://anapioficeandfire.com/api/houses/362"],"books":["https://anapioficeandfire.com/api/books/5"],"povBooks":["https://anapioficeandfire.com/api/books/1","https://anapioficeandfire.com/api/books/2","https://anapioficeandfire.com/api/books/3","https://anapioficeandfire.com/api/books/8"],"tvSeries":["Season 1","Season 2","Season 3","Season 4","Season 5","Season 6"],"playedBy":["Kit Harington"]}'

# %% [markdown]
# 3. Extract these data in JSON format:

# %%
r.headers
# Out:
# {'Date': 'Thu, 22 Feb 2024 14:56:58 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Strict-Transport-Security': 'max-age=2592000', 'X-Powered-By': 'ASP.NET', 'Cache-Control': 'max-age=2678400', 'CF-Cache-Status': 'HIT', 'Age': '78107', 'Last-Modified': 'Wed, 21 Feb 2024 17:15:11 GMT', 'Report-To': '{"endpoints":[{"url":"https:\\/\\/a.nel.cloudflare.com\\/report\\/v3?s=Wwit4RtwTM0yVEFle%2FBjOjKMpKtEihUE3Xm0m3Pg%2BdkjiGD07kEGPKGbVeM3WBIJSIyrzFQ2bMgzMhwA4wAQPPqWIMQcinhTRE%2F7bsKkkWE67r6lwFAMt5OjJJcivgOu0FYBJvF7YQ1KhpW%2BX0hxc0DN00A%3D"}],"group":"cf-nel","max_age":604800}', 'NEL': '{"success_fraction":0,"report_to":"cf-nel","max_age":604800}', 'Vary': 'Accept-Encoding', 'Server': 'cloudflare', 'CF-RAY': '8598142aec55d6a2-CDG', 'Content-Encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'}

# %%
r.json()
# Out:
# {'url': 'https://anapioficeandfire.com/api/characters/583',
#  'name': 'Jon Snow',
#  'gender': 'Male',
#  'culture': 'Northmen',
#  'born': 'In 283 AC',
#  'died': '',
#  'titles': ["Lord Commander of the Night's Watch"],
#  'aliases': ['Lord Snow',
#   "Ned Stark's Bastard",
#   'The Snow of Winterfell',
#   'The Crow-Come-Over',
#   "The 998th Lord Commander of the Night's Watch",
#   'The Bastard of Winterfell',
#   'The Black Bastard of the Wall',
#   'Lord Crow'],
#  'father': '',
#  'mother': '',
#  'spouse': '',
#  'allegiances': ['https://anapioficeandfire.com/api/houses/362'],
#  'books': ['https://anapioficeandfire.com/api/books/5'],
#  'povBooks': ['https://anapioficeandfire.com/api/books/1',
#   'https://anapioficeandfire.com/api/books/2',
#   'https://anapioficeandfire.com/api/books/3',
#   'https://anapioficeandfire.com/api/books/8'],
#  'tvSeries': ['Season 1',
#   'Season 2',
#   'Season 3',
#   'Season 4',
#   'Season 5',
#   'Season 6'],
#  'playedBy': ['Kit Harington']}

# %% [markdown]
# 4. Now extract the JSON keys you have obtained and create a DataFrame that will have the JSON keys you extracted as a column.
#
# **Hint**: we can use: `r.json().keys()`.

# %%
r = requests.get("https://anapioficeandfire.com/api/characters/583")
# We can use r.json().keys() in order to get an array of keys names
print("r.json().keys() == ", r.json().keys())
data = pd.DataFrame(columns = r.json().keys())
data.head()
# Out:
# r.json().keys() ==  dict_keys(['url', 'name', 'gender', 'culture', 'born', 'died', 'titles', 'aliases', 'father', 'mother', 'spouse', 'allegiances', 'books', 'povBooks', 'tvSeries', 'playedBy'])
# Empty DataFrame
# Columns: [url, name, gender, culture, born, died, titles, aliases, father, mother, spouse, allegiances, books, povBooks, tvSeries, playedBy]
# Index: []

# %% [markdown]
# 5. Create a loop to extract data from the firsts 150 characters of the series and add them to your DataFrame.

# %%
# First, we iterate over the firsts 150 characters
for i in range(1,151):
    # Make a request
    r = requests.get("https://anapioficeandfire.com/api/characters/{}".format(i))
    # Store it in our DataFrame
    data = data._append(r.json(), ignore_index=True)
    print("{} personnage done".format(i))
# Out:
# 1 personnage done
# 2 personnage done
# 3 personnage done
# 4 personnage done
# 5 personnage done
# 6 personnage done
# 7 personnage done
# 8 personnage done
# 9 personnage done
# 10 personnage done
# 11 personnage done
# 12 personnage done
# 13 personnage done
# 14 personnage done
# 15 personnage done
# 16 personnage done
# 17 personnage done
# 18 personnage done
# 19 personnage done
# 20 personnage done
# 21 personnage done
# 22 personnage done
# 23 personnage done
# 24 personnage done
# 25 personnage done
# 26 personnage done
# 27 personnage done
# 28 personnage done
# 29 personnage done
# 30 personnage done
# 31 personnage done
# 32 personnage done
# 33 personnage done
# 34 personnage done
# 35 personnage done
# 36 personnage done
# 37 personnage done
# 38 personnage done
# 39 personnage done
# 40 personnage done
# 41 personnage done
# 42 personnage done
# 43 personnage done
# 44 personnage done
# 45 personnage done
# 46 personnage done
# 47 personnage done
# 48 personnage done
# 49 personnage done
# 50 personnage done
# 51 personnage done
# 52 personnage done
# 53 personnage done
# 54 personnage done
# 55 personnage done
# 56 personnage done
# 57 personnage done
# 58 personnage done
# 59 personnage done
# 60 personnage done
# 61 personnage done
# 62 personnage done
# 63 personnage done
# 64 personnage done
# 65 personnage done
# 66 personnage done
# 67 personnage done
# 68 personnage done
# 69 personnage done
# 70 personnage done
# 71 personnage done
# 72 personnage done
# 73 personnage done
# 74 personnage done
# 75 personnage done
# 76 personnage done
# 77 personnage done
# 78 personnage done
# 79 personnage done
# 80 personnage done
# 81 personnage done
# 82 personnage done
# 83 personnage done
# 84 personnage done
# 85 personnage done
# 86 personnage done
# 87 personnage done
# 88 personnage done
# 89 personnage done
# 90 personnage done
# 91 personnage done
# 92 personnage done
# 93 personnage done
# 94 personnage done
# 95 personnage done
# 96 personnage done
# 97 personnage done
# 98 personnage done
# 99 personnage done
# 100 personnage done
# 101 personnage done
# 102 personnage done
# 103 personnage done
# 104 personnage done
# 105 personnage done
# 106 personnage done
# 107 personnage done
# 108 personnage done
# 109 personnage done
# 110 personnage done
# 111 personnage done
# 112 personnage done
# 113 personnage done
# 114 personnage done
# 115 personnage done
# 116 personnage done
# 117 personnage done
# 118 personnage done
# 119 personnage done
# 120 personnage done
# 121 personnage done
# 122 personnage done
# 123 personnage done
# 124 personnage done
# 125 personnage done
# 126 personnage done
# 127 personnage done
# 128 personnage done
# 129 personnage done
# 130 personnage done
# 131 personnage done
# 132 personnage done
# 133 personnage done
# 134 personnage done
# 135 personnage done
# 136 personnage done
# 137 personnage done
# 138 personnage done
# 139 personnage done
# 140 personnage done
# 141 personnage done
# 142 personnage done
# 143 personnage done
# 144 personnage done
# 145 personnage done
# 146 personnage done
# 147 personnage done
# 148 personnage done
# 149 personnage done
# 150 personnage done

# %%
data.head()
# Out:
#                                               url    name  gender   culture  \
# 0  https://anapioficeandfire.com/api/characters/1          Female  Braavosi
# 1  https://anapioficeandfire.com/api/characters/2  Walder    Male
# 2  https://anapioficeandfire.com/api/characters/3            Male
# 3  https://anapioficeandfire.com/api/characters/4          Female  Braavosi
# 4  https://anapioficeandfire.com/api/characters/5            Male
#
#   born died titles                     aliases father mother spouse  \
# 0               []  [The Daughter of the Dusk]
# 1               []                     [Hodor]
# 2               []                   [Lamprey]
# 3               []         [The Merling Queen]
# 4               []            [Old Crackbones]
#
#                                       allegiances  \
# 0                                              []
# 1  [https://anapioficeandfire.com/api/houses/362]
# 2   [https://anapioficeandfire.com/api/houses/15]
# 3                                              []
# 4                                              []
#
#                                                books povBooks  \
# 0        [https://anapioficeandfire.com/api/books/5]       []
# 1  [https://anapioficeandfire.com/api/books/1, ht...       []
# 2        [https://anapioficeandfire.com/api/books/3]       []
# 3  [https://anapioficeandfire.com/api/books/5, ht...       []
# 4        [https://anapioficeandfire.com/api/books/5]       []
#
#                                             tvSeries          playedBy
# 0                                                 []                []
# 1  [Season 1, Season 2, Season 3, Season 4, Seaso...  [Kristian Nairn]
# 2                                                 []                []
# 3                                                 []                []
# 4                                                 []                []

# %%
data.tail(5)
# Out:
#                                                    url            name  \
# 145   https://anapioficeandfire.com/api/characters/146      Arwyn Frey
# 146  https://www.anapioficeandfire.com/api/characte...  Arwyn Oakheart
# 147   https://anapioficeandfire.com/api/characters/148      Arya Stark
# 148   https://anapioficeandfire.com/api/characters/149   Arys Oakheart
# 149   https://anapioficeandfire.com/api/characters/150    Asha Greyjoy
#
#      gender   culture                          born  \
# 145  Female                               In 285 AC
# 146  Female
# 147  Female  Northmen      In 289 AC, at Winterfell
# 148    Male     Reach                    At Old Oak
# 149  Female  Ironborn  In 275 AC or 276 AC, at Pyke
#
#                              died  \
# 145
# 146
# 147
# 148  In 300 AC, at the Greenblood
# 149
#
#                                                 titles  \
# 145                                                 []
# 146                                  [Lady of Old Oak]
# 147                                         [Princess]
# 148                                              [Ser]
# 149  [Princess, Captain of the Black Wind, Conquero...
#
#                                                aliases father mother  \
# 145                                                 []
# 146                                                 []
# 147  [Arya Horseface, Arya Underfoot, Arry, Lumpyfa...
# 148                                                 []
# 149                    [Esgred, The Kraken's Daughter]
#
#                                                 spouse  \
# 145
# 146
# 147
# 148
# 149  https://anapioficeandfire.com/api/characters/1372
#
#                                            allegiances  \
# 145     [https://anapioficeandfire.com/api/houses/143]
# 146  [https://www.anapioficeandfire.com/api/houses/...
# 147     [https://anapioficeandfire.com/api/houses/362]
# 148     [https://anapioficeandfire.com/api/houses/286]
# 149  [https://anapioficeandfire.com/api/houses/169,...
#
#                                                  books  \
# 145  [https://anapioficeandfire.com/api/books/2, ht...
# 146  [https://www.anapioficeandfire.com/api/books/1...
# 147                                                 []
# 148  [https://anapioficeandfire.com/api/books/1, ht...
# 149  [https://anapioficeandfire.com/api/books/1, ht...
#
#                                               povBooks  \
# 145                                                 []
# 146                                                 []
# 147  [https://anapioficeandfire.com/api/books/1, ht...
# 148        [https://anapioficeandfire.com/api/books/5]
# 149  [https://anapioficeandfire.com/api/books/5, ht...
#
#                                               tvSeries           playedBy
# 145                                                 []                 []
# 146                                                 []                 []
# 147  [Season 1, Season 2, Season 3, Season 4, Seaso...  [Maisie Williams]
# 148                                                 []                 []
# 149                     [Season 2, Season 3, Season 4]     [Gemma Whelan]
